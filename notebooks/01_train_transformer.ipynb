# %% [markdown]
# # 01 — Train HookedTransformer on Shakespeare
#
# Owner: Mike C.

# %%
import sys
import torch
sys.path.insert(0, "../src")

from mid.config import load_configs
from mid.model.train import train, generate_sample

# %%
model_type = "decoder"
model_size = "small"

# %%
model_cfg, train_cfg = load_configs(f"../configs/model_{model_type}_{model_size}.yaml")
print(model_cfg)
print(train_cfg)
# Out:
# ModelConfig(d_model=128, d_head=32, n_heads=4, n_layers=4, d_mlp=512, d_vocab=3000, n_ctx=256, act_fn='gelu', normalization_type='LN', tokenizer_name=None, seed=16)
# TrainConfig(batch_size=64, learning_rate=0.0003, total_steps=10000, eval_interval=200, eval_batches=20)

# %%
model = train(model_cfg, model_type, model_size, train_cfg, tokenizer_dir="../tokenizer_output", out_dir="../checkpoints")
# Out:
# Device: cpu <-- Make sure 'cuda' if GPU is available
# Moving model to device:  cpu
# Model parameters: 1,597,112
# Step    200 | train 5.414 | val 5.540 * New best model
# Step    400 | train 4.943 | val 5.145 * New best model
# Step    600 | train 4.693 | val 4.958 * New best model
# Step    800 | train 4.510 | val 4.816 * New best model
# Step   1000 | train 4.367 | val 4.698 * New best model
# Step   1200 | train 4.263 | val 4.621 * New best model
# Step   1400 | train 4.189 | val 4.586 * New best model
# Step   1600 | train 4.120 | val 4.542 * New best model
# Step   1800 | train 4.061 | val 4.502 * New best model
# Step   2000 | train 4.025 | val 4.478 * New best model
# Step   2200 | train 3.973 | val 4.453 * New best model
# Step   2400 | train 3.934 | val 4.437 * New best model
# Step   2600 | train 3.896 | val 4.397 * New best model
# Step   2800 | train 3.854 | val 4.377 * New best model
# Step   3000 | train 3.826 | val 4.368 * New best model
# Step   3200 | train 3.784 | val 4.356 * New best model
# Step   3400 | train 3.727 | val 4.348 * New best model
# Step   3600 | train 3.714 | val 4.334 * New best model
# Step   3800 | train 3.702 | val 4.338
# Step   4000 | train 3.667 | val 4.305 * New best model
# Step   4200 | train 3.631 | val 4.312
# Step   4400 | train 3.599 | val 4.294 * New best model
# Step   4600 | train 3.599 | val 4.289 * New best model
# Step   4800 | train 3.575 | val 4.286 * New best model
# Step   5000 | train 3.541 | val 4.287
# Step   5200 | train 3.513 | val 4.275 * New best model
# Step   5400 | train 3.501 | val 4.279
# Step   5600 | train 3.498 | val 4.282
# Step   5800 | train 3.494 | val 4.277
# Step   6000 | train 3.452 | val 4.269 * New best model
# Step   6200 | train 3.430 | val 4.258 * New best model
# Step   6400 | train 3.410 | val 4.256 * New best model
# Step   6600 | train 3.400 | val 4.270
# Step   6800 | train 3.378 | val 4.259
# Step   7000 | train 3.393 | val 4.257
# Step   7200 | train 3.362 | val 4.269
# Step   7400 | train 3.362 | val 4.274
# Step   7600 | train 3.321 | val 4.265
# Step   7800 | train 3.323 | val 4.271
# Step   8000 | train 3.323 | val 4.277
# Step   8200 | train 3.299 | val 4.275
# Step   8400 | train 3.289 | val 4.299
# Step   8600 | train 3.276 | val 4.291
# Step   8800 | train 3.277 | val 4.293
# Step   9000 | train 3.249 | val 4.293
# Step   9200 | train 3.253 | val 4.302
# Step   9400 | train 3.236 | val 4.293
# Step   9600 | train 3.228 | val 4.323
# Step   9800 | train 3.212 | val 4.322
# Step  10000 | train 3.189 | val 4.332

# %%
# Sample testing
print('---------------SAMPLE 1: "HAMLET:\nTo be, or not"---------------')
generate_sample(model, tokenizer_path="../tokenizer_output/tokenizer.json", device="cuda")

print('---------------SAMPLE 2: "CORDELIA:"---------------')
generate_sample(model, tokenizer_path="../tokenizer_output/tokenizer.json", device="cuda", prompt="CORDELIA:")

print('---------------SAMPLE 3: "CAESAR:"---------------')
generate_sample(model, tokenizer_path="../tokenizer_output/tokenizer.json", device="cuda", prompt="CAESAR:")

print('---------------SAMPLE 4: "Whats done cant"---------------')
generate_sample(model, tokenizer_path="../tokenizer_output/tokenizer.json", device="cuda", prompt="What's done can't")
# Out:
# ---------------SAMPLE 1: "HAMLET:
# To be, or not"---------------
# HAMLET:
# To be, or not because to cut off.
# And I'll bring thee to my page of my heart,
# For I can it not be a glass of mine eye.
# My lords, if thou be'st not what I would be;
# I'll have avoided of my portage.
#
# HAMLET
# I am no cause, my lord, my heart shall be so.
#
# HAMLET
# I will conge him as I trust God and leave me.
#
# GRATIANO,
# But I am not like to tell you all the days.
#
# KING JOHN
# Fie, ay, in wrong, and a bloody deed.
#
# GHOST OF FRANCE
# You have letters, by merit and delay
# Of whatever to maintain questionless death,
# This I we may guess, although well so
# Cannot Angelo.
#
# KING  How now, what's your will?
#
#
# ---------------SAMPLE 2: "CORDELIA:"---------------
# CORDELIA:
# I'll not look to be ten thousand crowns.
#
# PROSPERO,   With that.
#
# MIRANDA,
# You have a world may be, and I'll say I.
#
# PROSPERO  The devil himself shall
# The histime does.
#
# MIRANDA  That's the curt thou dost;
# No, not thy garment love.
#
# PROSPERO  Ready, Cebelia.
# Mine own good night, Charmian, and peep
# This creature of her despairs.
#
# MIRANDA  Poor Palamon!
# Missing my sword, O!
#
# PROSPERO,
# How now, what thou art thou, wretch!
#
# MIRANDA Upon the corse, I think
# That I am sick by my life.
#
# PROSPERO  O, my good lord!
# Thy fault undearance cannot hold thee
# ---------------SAMPLE 3: "CAESAR:"---------------
# CAESAR:
# Shall you be friends? What may the King shall die?
#
# NORFOLK
# Why, this was his father's company
# And would not have to say 't, if he had,
# One days to him.
#
# Welcome, Cromlas, my lord.
#
# LORDS  What, art thou, Tigherous?
#
# WESTMORTION 'twas there, sir.
#
# BARNARDO
# That was engaged by him he carried,
# Flatter bells of tears.
#
# NORTHUMBERLAND  In manifts,
# I'll make my head from the injuries,
# But by the famous churchman, but by supperment
# Which forache hath received.
#
# NORTHUMBERLAND  My villain, I hope
# He had been conquer for a dismal of him.
#
# S
# ---------------SAMPLE 4: "Whats done cant"---------------
# What's done can't thou canst, sir?
#
# PALAMON  'Tis not sick.
#
# ARCITE  We have no more
# Than those that are so suddenly so much in
# As we are but boardy. Say thou 'rt in prison,
# Therefore thy preyetitor.
#
# PALAMON  You're a beast's a fool.
#
# ARCITE  You have all the world with me.
#
# PALAMON
# I am contented. I must needs be hid that
# Which you will; here I have not doubt.
#
# PALAMON  Yes, wise fellow.
#
# ARCITE
# Ay, answer none tomorrow.
#
# PALAMON  Let me hear.
#
# ARCITE  Thou hast mercy for thine own.
#
# PALAMON  What,
# I have a wretches!
#
# ARCITE  A fat man?
#
# ARCITE
# I thank thee for any ill.
#
# ARCITE  You're angry.
#
# PALAMON
# I thank you, sir.
#
# PALAMON
